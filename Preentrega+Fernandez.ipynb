# %% [markdown]
# # PRE ENTREGA TRABAJO FINAL
# # Dataset Préstamos bancarios
# ### RICARDO FERNANDEZ
# ### Comisión 45305

# %% [markdown]
# ### Origen csv   link :https://www.kaggle.com/datasets/zaurbegiev/my-dataset

# %% [markdown]
# <img src="Entrega.png" style="width:600px;height:300px;">

# %% [markdown]
# 1.	¿Cuáles son las tendencias en la toma de préstamos bancarios?
# 2.	¿Cómo se puede evaluar el riesgo de impagos de los préstamos bancarios?
# 3.	¿Cómo pueden los bancos mejorar la eficiencia en la asignación de recursos a través del análisis de datos de préstamos bancarios?
# 4.	¿Qué segmentos de clientes tienen un mayor riesgo de impagos y cómo se pueden mitigar estos riesgos?
# 5.	¿Qué oportunidades de crecimiento pueden identificarse a través del análisis de datos de préstamos bancarios?
# 6.	¿Cómo el historial crediticio y los ingresos estables pueden indicar la capacidad de un prestatario para devolver el préstamo?
# 7.	¿Existe una correlación entre el nivel de ingresos y la probabilidad de impago de los préstamos bancarios?
#
# Hipótesis:
# 1.	Existe una tendencia creciente en la toma de préstamos bancarios.
# 2.	La evaluación del riesgo de impagos de los préstamos bancarios puede ser realizada a través de la recopilación y análisis de datos relevantes.
# 3.	El análisis de datos de préstamos bancarios puede mejorar la eficiencia en la asignación de recursos y optimizar la salud financiera de los bancos.
# 4.	Los segmentos de clientes con un historial crediticio débil y ingresos inestables presentan un mayor riesgo de impagos.
# 5.	Existen oportunidades de crecimiento en determinados segmentos de mercado que pueden ser identificadas a través del análisis de datos de préstamos bancarios.
# 6.	Un historial crediticio sólido y un flujo de ingresos estable son indicadores positivos de que un prestatario será capaz de cumplir con sus obligaciones financieras.
# 7.	Existe una correlación positiva entre el nivel de ingresos y la probabilidad de impago de los préstamos bancarios.

# %% [markdown]
# ## ***1) Data Wrangling***

# %% [markdown]
# ### Importamos  Dataset en Jupyter Notebook

# %%
#Cargamos Pandas
import pandas as pd

# %%
bank_ls_train = pd.read_csv("credit_train.csv")

# %% [markdown]
# ### DICCIONARIO:
#
# 1.	Loan ID: Identificación del préstamo
# 2.	Customer ID: Identificación del cliente
# 3.	Loan Status: Estatus del préstamo
# 4.	Current Loan Amount: Cantidad actual del préstamo
# 5.	Term: Plazo
# 6.	Credit Score: Puntuación de crédito
# 7.	Annual Income: Ingreso anual
# 8.	Years in current job: Años en el trabajo actual
# 9.	Home Ownership: Propiedad de vivienda
# 10.	Purpose: Propósito
# 11.	Monthly Debt: Deuda mensual
# 12.	Years of Credit History: Años de historial de crédito
# 13.	Months since last delinquent: Meses desde el último incumplimiento
# 14.	Number of Open Accounts: Número de cuentas abiertas
# 15.	Number of Credit Problems: Número de créditos con problemas
# 16.	Current Credit Balance: Saldo actual de crédito
# 17.	Maximum Open Credit: Crédito abierto máximo
# 18.	Bankruptcies: Quiebras
# 19. Tax Liens: Pendiente de pago de impuestos

# %%
#Traemos las n primeras filas del DataFrame 
bank_ls_train.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
# ...

# %%
#Observamos  con Shape la forma del dataset.
bank_ls_train.shape
# Out:
# (100514, 19)

# %%
#Obtenemos informacion de las columnas 
bank_ls_train.info()
bank_ls_train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
# ...

# %% [markdown]
# **Accedemos al nombre de las columnas**

# %%
bank_ls_train.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
#Se mostrarán las últimas 5 filas 
bank_ls_train.tail()
# Out:
#        Loan ID Customer ID Loan Status  Current Loan Amount Term  \
# 100509     NaN         NaN         NaN                  NaN  NaN
# 100510     NaN         NaN         NaN                  NaN  NaN
# 100511     NaN         NaN         NaN                  NaN  NaN
# 100512     NaN         NaN         NaN                  NaN  NaN
# 100513     NaN         NaN         NaN                  NaN  NaN
#
#         Credit Score  Annual Income Years in current job Home Ownership  \
# 100509           NaN            NaN                  NaN            NaN
# 100510           NaN            NaN                  NaN            NaN
# 100511           NaN            NaN                  NaN            NaN
# 100512           NaN            NaN                  NaN            NaN
# 100513           NaN            NaN                  NaN            NaN
#
#        Purpose  Monthly Debt  Years of Credit History  \
# 100509     NaN           NaN                      NaN
# ...

# %%
# Cantidad de filas por columnas
bank_ls_train.count()
# Out:
# Loan ID                         100000
# Customer ID                     100000
# Loan Status                     100000
# Current Loan Amount             100000
# Term                            100000
# Credit Score                     80846
# Annual Income                    80846
# Years in current job             95778
# Home Ownership                  100000
# Purpose                         100000
# Monthly Debt                    100000
# Years of Credit History         100000
# Months since last delinquent     46859
# Number of Open Accounts         100000
# Number of Credit Problems       100000
# Current Credit Balance          100000
# Maximum Open Credit              99998
# Bankruptcies                     99796
# Tax Liens                        99990
# dtype: int64

# %% [markdown]
# **Con *isnull().sum()* es un método que me permite calcular la cantidad de valores NaN (Not a Number) en cada columna del DataFrame. El resultado devuelto será una serie de datos donde cada valor representa la cantidad de valores NaN en cada columna.**

# %%
#Revisamos el total de datos faltantes en las columnas con nulos
bank_ls_train.isnull().sum()
# Out:
# Loan ID                           514
# Customer ID                       514
# Loan Status                       514
# Current Loan Amount               514
# Term                              514
# Credit Score                    19668
# Annual Income                   19668
# Years in current job             4736
# Home Ownership                    514
# Purpose                           514
# Monthly Debt                      514
# Years of Credit History           514
# Months since last delinquent    53655
# Number of Open Accounts           514
# Number of Credit Problems         514
# Current Credit Balance            514
# Maximum Open Credit               516
# Bankruptcies                      718
# Tax Liens                         524
# dtype: int64

# %%
#Miramos el tipo de datos de cada columna, el número de no nulos en cada columna y el uso de memoria
bank_ls_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
# ...

# %% [markdown]
# **Veremos en estos  dos **mapas de calor**  la cantidad de valores faltantes en los dataset**

# %%
#Importar las librerias necesarias
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# Crear una matriz que muestre los valores faltantes en cada columna
msno.matrix(bank_ls_train)

# Crear un mapa de calor que muestre la correlación entre los valores faltantes en cada columna
sns.heatmap(bank_ls_train.isnull(), cmap='viridis')

# Agregar título y estilos a la figura
plt.title("Mapa de calor de valores faltantes en el conjunto de datos bank_ls_train", fontsize=20, fontweight='bold')
sns.set_style("whitegrid")

# Mostrar el gráfico
plt.show()

# %%
# Calculamos el porcentaje de valores nulos en cada columna del conjunto de datos bank_ls_train
null_porciento = 100*(bank_ls_train.isnull().sum()/len(bank_ls_train))

# Seleccionamos solo las columnas que tienen por lo menos un valor nulo y las ordenamos 
# de menor a mayor por su porcentaje de valores nulos
null_porciento = null_porciento[null_porciento>0].sort_values()

null_porciento
# Out:
# Loan ID                          0.511372
# Current Credit Balance           0.511372
# Number of Credit Problems        0.511372
# Number of Open Accounts          0.511372
# Years of Credit History          0.511372
# Monthly Debt                     0.511372
# Home Ownership                   0.511372
# Purpose                          0.511372
# Term                             0.511372
# Current Loan Amount              0.511372
# Loan Status                      0.511372
# Customer ID                      0.511372
# Maximum Open Credit              0.513361
# Tax Liens                        0.521320
# Bankruptcies                     0.714328
# Years in current job             4.711781
# Annual Income                   19.567423
# Credit Score                    19.567423
# Months since last delinquent    53.380624
# dtype: float64

# %% [markdown]
# **Esta función útil que permite eliminar columnas en un conjunto de datos que no tienen información en más del 50% de las filas. Este proceso de limpieza de datos ayuda a simplificar el conjunto de datos, mejorando su calidad y eficiencia en su posterior análisis. Con nuestra función, podemos automatizar este proceso y ahorrar tiempo en la limpieza de grandes conjuntos de datos."**

# %%
def eliminar_columnas_con_nulos(df):
    # Calculamos el porcentaje de valores nulos en cada columna del conjunto de datos
    null_porciento = 100*(df.isnull().sum()/len(df))
    
    # Seleccionamos solo las columnas que tienen más del 50% de valores nulos
    columnas_con_nulos = null_porciento[null_porciento > 50].index
    
    # Eliminamos las columnas seleccionadas del conjunto de datos
    df_sin_columnas_con_nulos = df.drop(columns=columnas_con_nulos)
    
    # Imprimimos las columnas eliminadas
    print("Columnas eliminadas:")
    print(columnas_con_nulos)
    
    return df_sin_columnas_con_nulos

# %%
# Ingreso bank_ls_train en la función para eliminar las columnas 
bank_ls_train = eliminar_columnas_con_nulos(bank_ls_train)
# Out:
# Columnas eliminadas:
# Index(['Months since last delinquent'], dtype='object')

# %%
# Volvemos a revisar las columnas como quedan
bank_ls_train .columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Number of Open Accounts', 'Number of Credit Problems',
#        'Current Credit Balance', 'Maximum Open Credit', 'Bankruptcies',
#        'Tax Liens'],
#       dtype='object')

# %% [markdown]
# **Duplicated() es un método en pandas, para detectar filas duplicadas en un DataFrame.**

# %%
bank_ls_train.duplicated().sum()
# Out:
# 10728

# %% [markdown]
# **Para eliminar duplicados utilizo la función *drop_duplicates* ya toma una serie de parámetros opcionales que me permiten especificar qué valores se consideran duplicados y cómo manejar esos duplicados.**

# %%
bank_ls_train.drop_duplicates(inplace = True)
bank_ls_train.shape
# Out:
# (89786, 18)

# %% [markdown]
# **Esta funcion utiliza un bucle "for" que registra todas las columnas numéricas del dataframe y calcula la mediana de cada una de ellas. Luego, utilice el método "fillna" de pandas para reemplazar los valores faltantes con la mediana calculada previamente. El parámetro "inplace=True" hace que los cambios se realicen directamente en el dataframe original.**
#
#
# **Por último, la función devuelve el marco de datos con los valores faltantes eliminados por la mediana.**
# **Este código parece ser una solución simple y efectiva para el problema de valores faltantes en un marco de datos**

# %%
# Funcion para reemplazar datos nulos por la MEDIANA
import pandas as pd

def fill_missing_with_median(df):
    for col in df.select_dtypes(include='number').columns:
        median = df[col].median()
        df[col].fillna(median, inplace=True)
    return df

# %%
# Apliacamos para nuestro dataframe bank_ls_train
bank_ls_train = fill_missing_with_median(bank_ls_train)

# %% [markdown]
#  **Se vuelve a revisar cuantos nulos ha quedado**

# %%
bank_ls_train.isnull().sum()
# Out:
# Loan ID                         1
# Customer ID                     1
# Loan Status                     1
# Current Loan Amount             0
# Term                            1
# Credit Score                    0
# Annual Income                   0
# Years in current job         3803
# Home Ownership                  1
# Purpose                         1
# Monthly Debt                    0
# Years of Credit History         0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %% [markdown]
# **Chequeamos como ha quedado nuestro dataframe**

# %%
#Importar las librerias necesarias
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# Crear una matriz que muestre los valores faltantes en cada columna
msno.matrix(bank_ls_train)

# Crear un mapa de calor que muestre la correlación entre los valores faltantes en cada columna
sns.heatmap(bank_ls_train.isnull(), cmap='viridis')

# Agregar título y estilos a la figura
plt.title("Mapa de calor de valores faltantes en el conjunto de datos bank_ls_train", fontsize=20, fontweight='bold')
sns.set_style("whitegrid")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **#Years in current job* es una columna que posee datos "object" por ello es la unica columna que han quedado con datos nulos.**

# %% [markdown]
# ### Outliers

# %% [markdown]
# **Como outliers en las variables numéricas, a veces no se deben eliminar porque pueden contener información importante, dependiendo de la variable numérica que estemos analizando. Por eso, a menudo construimos gráficas tipo "boxplot" de las columnas numéricas.**

# %%
#Graficamos un describe con colores gradientes para visualizar posibles outliers
temp = bank_ls_train.describe()
temp.style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# **Visualizamos de otra manera las columnas float64**

# %%
#La lista llamada "cols_num" que contiene los nombres de las columnas para las cuales se crearán los gráficos de caja.
cols_num = ["Current Loan Amount", "Credit Score","Annual Income",     
            "Monthly Debt", "Years of Credit History",
            "Number of Open Accounts",  
            "Number of Credit Problems","Current Credit Balance",
            "Maximum Open Credit", "Bankruptcies","Tax Liens"]


# El tamaño de la figura se establece en (8,30).
fig, axs = plt.subplots(nrows=len(cols_num), ncols=1, figsize=(12,45))

#La función "fig.subplots_adjust" para ajustar el espacio entre las filas del gráfico.
fig.subplots_adjust(hspace=0.5)

# El bucle "for" que itera sobre cada columna en "cols_num".
for i, col in enumerate(cols_num):
    sns.boxplot(data=bank_ls_train, x=col, ax=axs[i])
    axs[i].set_title(col)

# %% [markdown]
# **Para tratar los outliers voy utilizar el rango intercuartil (IQR) y multiplicarlo por un factor constante, por ejemplo, 1.5. El rango intercuartil es la diferencia entre el tercer cuartil (Q3) y el primer cuartil (Q1) de los datos. Los valores que están fuera de este rango se consideran outliers.**

# %%
# Columnas a procesar
cols_num = ["Credit Score", "Monthly Debt", "Current Credit Balance", "Maximum Open Credit"]

# Definir los límites de los valores aceptables
limits = {}
for col in cols_num:
    Q1 = bank_ls_train[col].quantile(0.25)
    Q3 = bank_ls_train[col].quantile(0.75)
    IQR = Q3 - Q1
    limits[col] = (Q1 - 1.5 * IQR, Q3 + 1.5 * IQR)

# Filtrar los outliers
for col in cols_num:
    bank_ls_train = bank_ls_train.loc[(bank_ls_train[col] >= limits[col][0]) & (bank_ls_train[col] <= limits[col][1])]

# %% [markdown]
# **Volvemos aplicar para observar como quedo nuestro dataset**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# La lista llamada "cols_num" que contiene los nombres de las columnas para las cuales se crearán los gráficos de caja.
cols_num = ["Current Loan Amount", "Credit Score","Annual Income",     
            "Monthly Debt", "Years of Credit History",
            "Number of Open Accounts",  
            "Number of Credit Problems","Current Credit Balance",
            "Maximum Open Credit", "Bankruptcies","Tax Liens"]

# Establecer los colores deseados para cada columna
colors = ['blue', 'green', 'red', 'orange', 'purple', 'pink', 'gray', 'brown', 'olive', 'teal', 'navy', 'maroon']

# El tamaño de la figura se establece en (8,30).
fig, axs = plt.subplots(nrows=len(cols_num), ncols=1, figsize=(12,45))

# La función "fig.subplots_adjust" para ajustar el espacio entre las filas del gráfico.
fig.subplots_adjust(hspace=0.5)

# El bucle "for" que itera sobre cada columna en "cols_num".
for i, col in enumerate(cols_num):
    sns.boxplot(data=bank_ls_train, x=col, ax=axs[i], color=colors[i])
    axs[i].set_title(col)

# %% [markdown]
# **Aquí se observa cómo se distribuyen los datos de la variable despúes de pasar por los diferentes arreglos.**

# %%
# Imprime la forma del DataFrame 'bank_ls_train'
print(bank_ls_train.shape)

# Genera un histograma para cada columna numérica en el DataFrame 'bank_ls_train'
# El parámetro 'bins' controla el número de barras en el histograma
# El parámetro 'figsize' controla el tamaño de la figura en pulgadas
bank_ls_train.hist(bins=40, figsize=(15,10))
# Out:
# (71407, 18)
# array([[<AxesSubplot:title={'center':'Current Loan Amount'}>,
#         <AxesSubplot:title={'center':'Credit Score'}>,
#         <AxesSubplot:title={'center':'Annual Income'}>],
#        [<AxesSubplot:title={'center':'Monthly Debt'}>,
#         <AxesSubplot:title={'center':'Years of Credit History'}>,
#         <AxesSubplot:title={'center':'Number of Open Accounts'}>],
#        [<AxesSubplot:title={'center':'Number of Credit Problems'}>,
#         <AxesSubplot:title={'center':'Current Credit Balance'}>,
#         <AxesSubplot:title={'center':'Maximum Open Credit'}>],
#        [<AxesSubplot:title={'center':'Bankruptcies'}>,
#         <AxesSubplot:title={'center':'Tax Liens'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ***00/CONCLUSIONES DATA WRANGLING**
#
# - Trabajamos con un dataset que cuenta 32051 registros y 12 columnas con atributos de cada cliente.
# - Se detectan valores faltantes en las variables loan_int_rate (tasa de interés del crédito) y person_emp_lenght (antiguedad del cliente en su trabajo).
# - En la tasa de interés del crédito, los valores faltantes ascienden a casi el 9.5% de la base. Dado que no tiene una distribución normal, optamos por calcular la mediana de la variable, y aplicarla a los missing values.
# - Mientras que en la duración del cliente en su trabajo, reemplazamos por 0 dado que entendemos que son personas recién ingresadas en su trabajo. Por lo tanto la duración es de 0 años. En esta variable, los missing values ascendían a un poco más del 2% del total.
#
# - Se detectan valores outliers en las variables person_age (edad del cliente), person_income (ingreso anual del cliente), y person_emp_lenght (la ya mencionada antiguedad del cliente en su trabajo).
# - Tras visualizarlos en gráficos, y dado a los clientes que brindamos nuestro servicio, curamos el dataset con los siguientes items:
#     - Limitamos la edad máxima a 80 años, dado que no nos interesan clientes mayores.
#     - Colocamos un ingreso máximo de 800.000 USD anuales, avisandole a los clientes que contraten nuestros servicios, que deberían otorgar un status premium (prestamo casi automatico, se deberia chequear su destino y su situación global financiera) a aquellos potenciales clientes que se presenten con ingresos demostrables mayor a este número.
#     - Finalmente, para la antiguedad de una persona en su trabajo, dejamos un máximo de 30 años./***

# %% [markdown]
# # **Análisis Exploratorio de Datos (EDA)**

# %% [markdown]
# Préstamos aprobados y rechazados

# %%
import plotly.express as px

# Calcular el porcentaje de préstamos aprobados y rechazados
loan_status_counts = round(bank_ls_train["Loan Status"].value_counts() / bank_ls_train.shape[0] * 100, 2)

# Crear un gráfico de pastel usando Plotly
fig = px.pie(
    loan_status_counts,
    values='Loan Status',
    names=["Aprobados", "Rechazados"],
    title='Porcentaje de préstamos aprobados/rechazados',
    color=["Aprobados", "Rechazados"],
    color_discrete_map={"Aprobados": "g", "Rechazados": "r"}
)
# Ajustar el tamaño del gráfico
fig.update_layout(
    width=500,
    height=500
)
fig.show()

# %%
import plotly.express as px

# Crear un gráfico de barras usando Plotly
fig = px.histogram(
    bank_ls_train,
    x="Term",
    color="Term",
    title="Conteo de préstamos por plazo",
    color_discrete_sequence=px.colors.qualitative.Set1
)

# Ajustar el tamaño del gráfico
fig.update_layout(
    width=500,
    height=500
)

fig.show()

# %% [markdown]
# ### Años en el trabajo actual = Years in current job
#
#  El siguiente gráfico  de barras  muestra la cantidad de veces que aparece cada valor en la columna "Years in current job" del conjunto de datos bank_ls_train, utilizando un esquema de colores especificado y mostrando las barras en orden de frecuencia.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crea una figura con un tamaño de 500x500
plt.figure(figsize=(500/60, 500/60))

# Crea un gráfico de barras que muestre la cantidad de clientes que han estado en su trabajo actual durante una cierta cantidad de años
sns.countplot(x=bank_ls_train["Years in current job"], palette="Set1", order=bank_ls_train["Years in current job"].value_counts().index)

# Establece el título del gráfico
plt.suptitle("Años en el trabajo actual ", fontsize=16)

# Establece las etiquetas de los ejes x e y
plt.xlabel("Años")
plt.ylabel("Cantidad")

# Muestra el gráfico
plt.show()

# %% [markdown]
# ### Se analiza Home Ownership = Propiedad de la vivienda

# %%
# Se crea una figura de un tamaño
plt.figure(figsize=(500/60, 500/60))

# # Crea un gráfico de recuento utilizando la columna Propiedad de la vivienda del conjunto de datos bank_ls_train
sns.countplot(x= bank_ls_train["Home Ownership"], palette="Set2")

# Titulo de plot
plt.title('Number of Home Ownerships')

# Muestra plot
plt.show()

# %% [markdown]
# ### Decuerdo con estos datos y sus distribuciones, las personas que toman préstamos tienen la siguiente distribución que se reduce de:  Vivienda Hipotecada=Home Mortgage,  Renta=Rent  ,  Vivienda propia=Own Home y  Tiene hipoteca=HaveMortgage

# %%
# Propósitos de préstamo más frecuentes

# Obtener el orden de los valores de la columna "Purpose" según su frecuencia
purpose_order = bank_ls_train["Purpose"].value_counts().index

# Crear una figura con un tamaño de 12x6
plt.figure(figsize=(12, 6))

# Crear un gráfico de barras horizontal con los datos de la columna "Purpose" del DataFrame bank_ls_train
sns.countplot(y= bank_ls_train["Purpose"], order=purpose_order, palette="Set2")

# Agregar un título al gráfico
plt.title("Propósitos de préstamo más frecuentes", fontsize=18)

# Agregar un título al eje x
plt.xlabel("Número de préstamos", fontsize=16)

# Agregar un título al eje y
plt.ylabel("Propósito", fontsize=16)

# Establecer tamaño de las etiquetas del eje x
plt.xticks(fontsize=14)

# Establecer tamaño de las etiquetas del eje y
plt.yticks(fontsize=14)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Con el método generate de la clase WordCloud creamos una la nube de palabras

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Crea una figura con un tamaño de 12x6 pulgadas
plt.subplots(figsize=(15,10))

# Convierte los elementos de la columna "Purpose" a strings y genera una nube de palabras
wordcloud = WordCloud(background_color='White', width=800, height=720).generate(" ".join(bank_ls_train['Purpose'].astype(str)))

# Muestra la nube de palabras
plt.imshow(wordcloud)

# Oculta los ejes del gráfico
plt.axis('off')

# Muestra el gráfico
plt.show()

# %% [markdown]
# ## ***2) Correlaciones y dependencias***

# %% [markdown]
# ### Matriz de correlación

# %%
# Importar las librerías necesarias
import matplotlib.pyplot as plt
import seaborn as sns

# Especificar el tamaño de la figura
plt.figure(figsize=(20, 12))

# Crear un heatmap a partir de la matriz de correlación del conjunto de datos bank_ls_train
sns.heatmap(bank_ls_train.corr(numeric_only=True), annot=True)

# Agregar título y estilos a la figura
plt.title("Heatmap de correlación del conjunto de datos bank_ls_train", fontsize=20, fontweight='bold')
sns.set_style("whitegrid")

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Especificar el tamaño de la figura
plt.figure(figsize=(12, 6))

# Obtener la matriz de correlación del conjunto de datos bank_ls_train
corr = bank_ls_train.corr(numeric_only=True)

# Especificar los valores mínimo y máximo para el filtrado
val_min = 0.57
val_max = 0.8

# Filtrar la matriz de correlación para mostrar solo las correlaciones dentro del rango especificado
mask = np.logical_or(corr < val_min, corr > val_max)
corr = corr.where(~mask)

# Eliminar las filas y columnas que no cumplen con las condiciones de filtrado
corr.dropna(axis=0, how='all', inplace=True)
corr.dropna(axis=1, how='all', inplace=True)

# Crear un heatmap a partir de la matriz de correlación filtrada
sns.heatmap(corr, annot=True)

# Agregar título y estilos a la figura
plt.title("Heatmap reducido por mayor correlación\n", fontsize=20, fontweight='bold')
sns.set_style("whitegrid")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Una correlación de 0.7 entre Number of Credit Problems y Bankruptcies, a su vez se observa que Maximun Open Credit y Current Credit Balance tiene 0.7 de corelacion y menor medida entre Tax Liens y Number of Credit Problems con una corelación de 0.57

# %% [markdown]
# ### Number of Credit Problems y Bankruptcies

# %%
plt.figure(figsize=(12, 6))

plt.xlabel('Número de problemas de crédito')
sns.regplot(x=bank_ls_train['Number of Credit Problems'],y=bank_ls_train['Bankruptcies'])
plt.ylabel('Quiebras')
plt.title('Número de problemas de crédito vs Quiebras')
plt.show()

# %%
# Crear una figura con dos subplots (uno para cada histograma)
fig, axes = plt.subplots(figsize=(12,6), ncols=2, sharex='all')

# Crear el primer histograma para visualizar la distribución de la columna 'Bankruptcies' para los casos en los que 'Bankruptcies' es 0 (sin bancarrota)
sns.histplot(data=bank_ls_train[bank_ls_train['Bankruptcies'] == 0], x='Bankruptcies', kde=True, ax=axes[0], color="green")
axes[0].set_title("Quiebra")

# Crear el segundo histograma para visualizar la distribución de la columna 'Number of Credit Problems' para los casos en los que 'Bankruptcies' es 1 (con bancarrota)
sns.histplot(data=bank_ls_train[bank_ls_train['Number of Credit Problems'] == 1], x='Number of Credit Problems', kde=True, ax=axes[1], color="red")
axes[1].set_title("Número de créditos com problemas")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Aplicamos la Correlacion de Pearsonr para observar la correlacion entre Número de problemas de crédito vs Quiebras

# %%
# Importamos la función pearsonr de la librería scipy.stats
from scipy.stats import pearsonr

# Asignamos las variables x e y con los valores de dos columnas de una tabla
# (en este caso "Number of Credit Problems" y "Tax Liens")
x = bank_ls_train['Number of Credit Problems']
y = bank_ls_train['Bankruptcies']

# Calculamos la correlación de Pearson entre las variables x e y y almacenamos
# el resultado en la variable "corr"
corr, _ = pearsonr(x, y)

# Imprimimos el resultado de la correlación
print('Correlación de Pearson: ', corr)
# Out:
# Correlación de Pearson:  0.7598209507375522

# %% [markdown]
# ### Maximun Open Credit y Current Credit Balance

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x=bank_ls_train['Maximum Open Credit'],y=bank_ls_train['Current Credit Balance'])
plt.xlabel('Crédito Maximo Abierto')
plt.ylabel('Saldo actual de crédito')
plt.title('Crédito Maximo Abierto vs Saldo actual de crédito')
plt.show()

# %%
# Crear una figura con dos subplots (uno para cada histograma)
fig, axes = plt.subplots(figsize=(12,6), ncols=2, sharex='all')

# Crear el primer histograma para visualizar la distribución de la columna 'Maximum Open Credit' para los casos en los que 'Bankruptcies' es 0 (sin bancarrota)
sns.histplot(data=bank_ls_train[bank_ls_train['Maximum Open Credit'] == 0], x='Maximum Open Credit', kde=True, ax=axes[0], color="green")
axes[0].set_title("Crédito Maximo Abierto")

# Crear el segundo histograma para visualizar la distribución de la columna 'Current Credit Balance' para los casos en los que 'Bankruptcies' es 1 (con bancarrota)
sns.histplot(data=bank_ls_train[bank_ls_train['Current Credit Balance'] == 1], x='Current Credit Balance', kde=True, ax=axes[1], color="red")
axes[1].set_title("Saldo actual de crédito")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Aplicamos la Correlacion de Pearsonr para observar la correlacion entre *Crédito Maximo Abierto vs Saldo actual de crédito*

# %%
# Importamos la función pearsonr de la librería scipy.stats
from scipy.stats import pearsonr

# Asignamos las variables x e y con los valores de dos columnas de una tabla
# (en este caso "Number of Credit Problems" y "Tax Liens")
x = bank_ls_train['Number of Credit Problems']
y = bank_ls_train['Bankruptcies']

# Calculamos la correlación de Pearson entre las variables x e y y almacenamos
# el resultado en la variable "corr"
corr, _ = pearsonr(x, y)

# Imprimimos el resultado de la correlación
print('Correlación de Pearson: ', corr)
# Out:
# Correlación de Pearson:  0.7598209507375522

# %% [markdown]
# ###  Tax Liens y Number of Credit Problems

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x=bank_ls_train['Number of Credit Problems'],y=bank_ls_train['Tax Liens'])
plt.xlabel('Número de créditos con problemas}')
plt.ylabel('Gravámenes Fiscales')
plt.title('Número de problemas de crédito vs Gravámenes Fiscales')
plt.show()

# %%
# Crear una figura con dos subplots (uno para cada histograma)
fig, axes = plt.subplots(figsize=(12,6), ncols=2, sharex='all')

# Crear el primer histograma para visualizar la distribución de la columna 'Number of Credit Problems' para los casos en los que 'Bankruptcies' es 0 (sin bancarrota)
sns.histplot(data=bank_ls_train[bank_ls_train['Number of Credit Problems'] == 0], x='Number of Credit Problems', kde=True, ax=axes[0], color="green")
axes[0].set_title("Número de créditos con problemas")

# Crear el segundo histograma para visualizar la distribución de la columna 'Tax Liens' para los casos en los que 'Bankruptcies' es 1 (con bancarrota)
sns.histplot(data=bank_ls_train[bank_ls_train['Tax Liens'] == 1], x='Tax Liens', kde=True, ax=axes[1], color="red")
axes[1].set_title("Gravámenes Fiscales")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Aplicamos la Correlacion de Pearsonr para observar la correlacion entre *Número de problemas de crédito vs Gravámenes Fiscales*

# %%
# Importamos la función pearsonr de la librería scipy.stats
from scipy.stats import pearsonr

# Asignamos las variables x e y con los valores de dos columnas de una tabla
# (en este caso "Number of Credit Problems" y "Tax Liens")
x = bank_ls_train['Number of Credit Problems']
y = bank_ls_train['Tax Liens']

# Calculamos la correlación de Pearson entre las variables x e y y almacenamos
# el resultado en la variable "corr"
corr, _ = pearsonr(x, y)

# Imprimimos el resultado de la correlación
print('Correlación de Pearson: ', corr)
# Out:
# Correlación de Pearson:  0.572873134951359

# %% [markdown]
# CRÉDITOS CON PROBLEMAS VS GRAVÁMENES FISCALES:  Que la correlación de Pearson de 0.57 nos indica que hay una correlación moderada entre las dos variables. Esto significa que a medida que "Crédito con Problemas" aumente , "Gravámenes Fiscales" tiende a aumentar de manera predecible.
